# %%
import sys
import numpy as np
import open3d
python_root = '../'
sys.path.insert(0, python_root)

from tools import pathconfig

from tools.visualization import get_lines_world_coordinates_with_instances
from tools.visualization import pcl_lines_for_plot
# Out:
# visualization.py: Using values in config_paths_and_variables.sh for SCENENET_SCRIPTS_PATH, LINESANDIMAGESFOLDER_PATH.

# %% [markdown]
# # Draw all the lines in the trajectory

# %% [markdown]
# **Note**: if `read_as_pickle` is `False`, then the data for the lines is read from the textfiles generated by the line detector and that are assumed to be stored in the paths defined in the configuration file `python/config_paths_and_variables.sh` as `SCENENET_SCRIPTS_PATH` and `LINESANDIMAGESFOLDER_PATH`.
# If instead `read_as_pickle` is `True`, then the data for the lines is read from the pickle files, that are assumed to be stored in the paths defined in the configuration file `python/config_paths_and_variables.sh` as `PICKLEANDSPLIT_PATH`. **Note**: pickle files also contain the virtual-camera images, so loading them in memory will cause all the virtual-camera images in the trajectory to also be loaded in memory, which is overkill when one just wants to display lines. If setting `read_as_pickle = True`, make sure to have enough memory to load all the data.

# %%
# Index of the trajectory.
traj = 1
# Total number of frames in the trajectory. For SceneNetRGBD this is 300, i.e., each trajectory contains 300 frames.
frames_total = 300
# Dataset name. For SceneNetRGBD valid values are 'val' or 'train_NUM', where NUM is a number between 0 and 16.
# Other valid names are 'scenenn', for dataset SceneNN.
dataset_name = 'train_0'
# True to read data for the lines from the pickle files, False otherwise.
read_as_pickle = False

if read_as_pickle:
    pickleandsplit_path = pathconfig.obtain_paths_and_variables("PICKLEANDSPLIT_PATH")
    pickle_files = [os.path.join(pickleandsplit_path, dataset_name, 'traj_{}'.format(traj), 'pickled_{}.pkl'.format(word)) \
                    for word in ['test', 'train', 'val']]
    from sklearn.externals import joblib
    from tools.pickle_dataset import merge_pickled_dictionaries
    pickled_dict = {}
    for pickle_file in pickle_files:
        temp_dict = joblib.load(pickle_file)
        merge_pickled_dictionaries(pickled_dict, temp_dict)
    pickled_labels = []
    for dataset_name in pickled_dict.keys():
            dataset_name_dict = pickled_dict[dataset_name]
            for trajectory_number in dataset_name_dict.keys():
                trajectory_number_dict = dataset_name_dict[trajectory_number]
                for frame_number in trajectory_number_dict.keys():
                    frame_number_dict = trajectory_number_dict[frame_number]
                    for image_type in frame_number_dict.keys():
                        image_type_dict = frame_number_dict[image_type]
                        for line_number in image_type_dict.keys():
                            line_number_dict = image_type_dict[line_number]
                            if image_type == 'rgb':
                                # Append label.
                                pickled_labels.append(line_number_dict['labels'])

    data_lines_world = np.array(pickled_labels, dtype=np.float32)
    
else:
    data_lines_world = get_lines_world_coordinates_with_instances(dataset_name=dataset_name, trajectory=traj,
                                                                  frames=[i for i in range(frames_total)])
# Out:
# visualization.py/get_lines_world_coordinates_with_instances: using /media/francesco/101f61e3-7b0d-4657-b369-3b79420829b8/francesco/ETH/Semester_3/Semester_Project/pySceneNetRGBD/data/scenenet_rgbd_train_0.pb as protobuf_path
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_0.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_1.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_2.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_3.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_4.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_5.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_6.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_7.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_8.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_9.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_10.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_11.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_12.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_13.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_14.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_15.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_16.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_17.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_18.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_19.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_20.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_21.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_22.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_23.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_24.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_25.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_26.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_27.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_28.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_29.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_30.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_31.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_32.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_33.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_34.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_35.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_36.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_37.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_38.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_39.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_40.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_41.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_42.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_43.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_44.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_45.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_46.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_47.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_48.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_49.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_50.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_51.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_52.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_53.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_54.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_55.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_56.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_57.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_58.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_59.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_60.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_61.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_62.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_63.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_64.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_65.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_66.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_67.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_68.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_69.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_70.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_71.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_72.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_73.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_74.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_75.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_76.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_77.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_78.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_79.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_80.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_81.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_82.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_83.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_84.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_85.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_86.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_87.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_88.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_89.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_90.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_91.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_92.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_93.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_94.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_95.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_96.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_97.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_98.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_99.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_100.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_101.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_102.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_103.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_104.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_105.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_106.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_107.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_108.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_109.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_110.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_111.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_112.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_113.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_114.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_115.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_116.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_117.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_118.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_119.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_120.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_121.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_122.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_123.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_124.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_125.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_126.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_127.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_128.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_129.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_130.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_131.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_132.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_133.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_134.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_135.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_136.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_137.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_138.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_139.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_140.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_141.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_142.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_143.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_144.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_145.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_146.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_147.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_148.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_149.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_150.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_151.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_152.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_153.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_154.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_155.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_156.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_157.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_158.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_159.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_160.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_161.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_162.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_163.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_164.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_165.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_166.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_167.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_168.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_169.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_170.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_171.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_172.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_173.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_174.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_175.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_176.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_177.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_178.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_179.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_180.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_181.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_182.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_183.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_184.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_185.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_186.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_187.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_188.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_189.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_190.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_191.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_192.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_193.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_194.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_195.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_196.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_197.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_198.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_199.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_200.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_201.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_202.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_203.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_204.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_205.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_206.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_207.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_208.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_209.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_210.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_211.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_212.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_213.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_214.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_215.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_216.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_217.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_218.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_219.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_220.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_221.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_222.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_223.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_224.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_225.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_226.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_227.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_228.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_229.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_230.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_231.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_232.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_233.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_234.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_235.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_236.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_237.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_238.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_239.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_240.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_241.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_242.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_243.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_244.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_245.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_246.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_247.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_248.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_249.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_250.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_251.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_252.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_253.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_254.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_255.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_256.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_257.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_258.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_259.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_260.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_261.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_262.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_263.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_264.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_265.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_266.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_267.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_268.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_269.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_270.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_271.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_272.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_273.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_274.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_275.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_276.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_277.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_278.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_279.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_280.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_281.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_282.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_283.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_284.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_285.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_286.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_287.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_288.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_289.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_290.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_291.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_292.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_293.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_294.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_295.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_296.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_297.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_298.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_299.txt
# Length of lines_world is 300
# Total number of lines: 21178
# Number of unique instance labels for lines: 46

# %%
# Generate pointcloud to plot.
pcl_lines_open3d = pcl_lines_for_plot(data_lines=data_lines_world[:], 
                                      lines_color=data_lines_world[:,-1].astype(np.int64),
                                      visualizer='open3d')

# %%
open3d.draw_geometries(pcl_lines_open3d[:])

# %% [markdown]
# # Draw only lines in test set

# %% [markdown]
# The data is split by the script `python/split_dataset_with_labels_world.py` in `train`, `test` and `val` sets, that can later be used for training. Here we only display lines in the `test` set.

# %%
# According to ../split_dataset_with_labels_world.py.
if read_as_pickle:
    pickleandsplit_path = pathconfig.obtain_paths_and_variables("PICKLEANDSPLIT_PATH")
    pickle_file = os.path.join(pickleandsplit_path, dataset_name, 'traj_{}'.format(traj), 'pickled_test.pkl')
    from sklearn.externals import joblib
    pickled_dict = joblib.load(pickle_file)
    for dataset_name in pickled_dict.keys():
            dataset_name_dict = pickled_dict[dataset_name]
            for trajectory_number in dataset_name_dict.keys():
                trajectory_number_dict = dataset_name_dict[trajectory_number]
                for frame_number in trajectory_number_dict.keys():
                    frame_number_dict = trajectory_number_dict[frame_number]
                    for image_type in frame_number_dict.keys():
                        image_type_dict = frame_number_dict[image_type]
                        for line_number in image_type_dict.keys():
                            line_number_dict = image_type_dict[line_number]
                            if image_type == 'rgb':
                                # Append label.
                                pickled_labels.append(line_number_dict['labels'])

    data_lines_world = np.array(pickled_labels, dtype=np.float32)
else:
    test = []
    for frame_id in range(frames_total):
        if frame_id % 5 == 3:
            test.append(frame_id)
            continue
    data_lines_world = get_lines_world_coordinates_with_instances(dataset_name=dataset_name, trajectory=traj,
                                                                  frames=test)
# Out:
# visualization.py/get_lines_world_coordinates_with_instances: using /media/francesco/101f61e3-7b0d-4657-b369-3b79420829b8/francesco/ETH/Semester_3/Semester_Project/pySceneNetRGBD/data/scenenet_rgbd_train_0.pb as protobuf_path
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_3.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_8.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_13.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_18.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_23.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_28.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_33.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_38.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_43.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_48.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_53.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_58.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_63.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_68.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_73.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_78.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_83.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_88.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_93.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_98.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_103.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_108.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_113.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_118.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_123.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_128.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_133.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_138.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_143.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_148.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_153.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_158.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_163.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_168.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_173.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_178.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_183.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_188.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_193.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_198.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_203.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_208.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_213.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_218.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_223.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_228.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_233.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_238.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_243.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_248.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_253.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_258.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_263.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_268.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_273.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_278.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_283.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_288.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_293.txt
# path_to_lines is /home/francesco/catkin_extended_ws/src/line_tools/data/train_0_lines/traj_1/lines_with_labels_298.txt
# Length of lines_world is 60
# Total number of lines: 4128
# Number of unique instance labels for lines: 36

# %%
# Generate pointcloud to plot.
pcl_lines_open3d = pcl_lines_for_plot(data_lines=data_lines_world[:], 
                                      lines_color=data_lines_world[:,-1].astype(np.int64),
                                      visualizer='open3d')

# %%
open3d.draw_geometries(pcl_lines_open3d[:])
